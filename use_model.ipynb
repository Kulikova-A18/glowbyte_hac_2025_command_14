# %%
import pickle
import pandas as pd
import numpy as np
import sklearn

# %%
try:
    import joblib
    model = joblib.load('model.pkl')
    print('Модель загружена через joblib!')
    print(f'Тип модели: {type(model)}')
except Exception as e:
    print(f'Ошибка joblib: {e}')
# Out:
# Модель загружена через joblib!
# Тип модели: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
